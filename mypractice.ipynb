# %%
import pandas as pd

# %%
miami_heat = pd.DataFrame(
    {
        'Age': [27, 29, 23, 31, 30],
        'Position': ['PG', 'SG', 'SF', 'PF', 'C'],
        'Salary': [10_000_000, 30_000_000, 45_000_000, 7_000_000, 20_000_000],
        'Starting?': [True, True, True, True, True],
    },
    index=['Mario Chalmers', 'Dwayne Wade', 'LeBron James', 'Shane Battier', 'Chris Bosh']
)

# %%
miami_heat
# Out:
#                 Age Position    Salary  Starting?
# Mario Chalmers   27       PG  10000000       True
# Dwayne Wade      29       SG  30000000       True
# LeBron James     23       SF  45000000       True
# Shane Battier    31       PF   7000000       True
# Chris Bosh       30        C  20000000       True

# %%
miami_heat.head(4)
# Out:
#                 Age Position    Salary  Starting?
# Mario Chalmers   27       PG  10000000       True
# Dwayne Wade      29       SG  30000000       True
# LeBron James     23       SF  45000000       True
# Shane Battier    31       PF   7000000       True

# %%
miami_heat.tail(2)
# Out:
#                Age Position    Salary  Starting?
# Shane Battier   31       PF   7000000       True
# Chris Bosh      30        C  20000000       True

# %%
miami_heat['Age']
# Out:
# Mario Chalmers    27
# Dwayne Wade       29
# LeBron James      23
# Shane Battier     31
# Chris Bosh        30
# Name: Age, dtype: int64

# %%
miami_heat.loc['LeBron James': 'Chris Bosh'][(miami_heat['Age'] <= 30)]
# Out:
# C:\Users\JJack\AppData\Local\Temp\ipykernel_32396\1178356240.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   miami_heat.loc['LeBron James': 'Chris Bosh'][(miami_heat['Age'] <= 30)]
#               Age Position    Salary  Starting?
# LeBron James   23       SF  45000000       True
# Chris Bosh     30        C  20000000       True

# %%
miami_heat.iloc[2, 0]
# Out:
# np.int64(23)

# %%
miami_heat.iat[1, 2]
# Out:
# np.int64(30000000)

# %%
miami_heat.at['LeBron James', 'Position']
# Out:
# 'SF'

# %%
miami_heat.info() # Provdies overview of DataFrame
# Out:
# <class 'pandas.DataFrame'>
# Index: 5 entries, Mario Chalmers to Chris Bosh
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        5 non-null      int64
#  1   Position   5 non-null      str
#  2   Salary     5 non-null      int64
#  3   Starting?  5 non-null      bool
# dtypes: bool(1), int64(2), str(1)
# memory usage: 337.0+ bytes

# %%
miami_heat.size # returns number of data places in DataFrame
# Out:
# 20

# %%
f'${miami_heat['Salary'].mean():,.2f}'
# Out:
# '$22,400,000.00'

# %%
miami_heat.drop('Chris Bosh') # Only displays DatFrame without Chris Bosh index row
# Out:
#                 Age Position    Salary  Starting?
# Mario Chalmers   27       PG  10000000       True
# Dwayne Wade      29       SG  30000000       True
# LeBron James     23       SF  45000000       True
# Shane Battier    31       PF   7000000       True

# %%
miami_heat.loc['Chris Bosh']
# Out:
# Age                30
# Position            C
# Salary       20000000
# Starting?        True
# Name: Chris Bosh, dtype: object

# %%
miami_heat.drop('Chris Bosh', inplace=True) # Permanently removes Chris Bosh from DataFrame due to inplace param being set to True

# %%
miami_heat.loc['Chris Bosh'] # No longer in DataFrame
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\JJack\Python Practice\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
miami_heat.sample()
# Out:
#                Age Position   Salary  Starting?
# Shane Battier   31       PF  7000000       True

# %%
miami_heat.describe()
# Out:
#             Age        Salary
# count   4.00000  4.000000e+00
# mean   27.50000  2.300000e+07
# std     3.41565  1.786990e+07
# min    23.00000  7.000000e+06
# 25%    26.00000  9.250000e+06
# 50%    28.00000  2.000000e+07
# 75%    29.50000  3.375000e+07
# max    31.00000  4.500000e+07

# %%
miami_heat.columns
# Out:
# Index(['Age', 'Position', 'Salary', 'Starting?'], dtype='str')

# %%
miami_heat.index
# Out:
# Index(['Mario Chalmers', 'Dwayne Wade', 'LeBron James', 'Shane Battier'], dtype='str')

# %%
miami_heat
# Out:
#                 Age Position    Salary  Starting?
# Mario Chalmers   27       PG  10000000       True
# Dwayne Wade      29       SG  30000000       True
# LeBron James     23       SF  45000000       True
# Shane Battier    31       PF   7000000       True

# %%
miami_heat.describe()
# Out:
#             Age        Salary
# count   4.00000  4.000000e+00
# mean   27.50000  2.300000e+07
# std     3.41565  1.786990e+07
# min    23.00000  7.000000e+06
# 25%    26.00000  9.250000e+06
# 50%    28.00000  2.000000e+07
# 75%    29.50000  3.375000e+07
# max    31.00000  4.500000e+07

# %%
miami_heat.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4 entries, Mario Chalmers to Shane Battier
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        4 non-null      int64
#  1   Position   4 non-null      str
#  2   Salary     4 non-null      int64
#  3   Starting?  4 non-null      bool
# dtypes: bool(1), int64(2), str(1)
# memory usage: 304.0+ bytes

# %%
miami_heat
# Out:
#                 Age Position    Salary  Starting?
# Mario Chalmers   27       PG  10000000      False
# Dwayne Wade      29       SG  30000000      False
# LeBron James     23       SF  45000000      False
# Shane Battier    31       PF   7000000      False
